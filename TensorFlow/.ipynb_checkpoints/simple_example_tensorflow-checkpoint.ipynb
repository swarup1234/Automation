# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
observations = 1000

xs = np.random.uniform(low=-10, high=10, size =(observations,1))
zs = np.random.uniform(-10,10,(observations,1))

generated_inputs = np.column_stack((xs,zs))
noise = np.random.uniform(-1,1, (observations,1))

generated_targets = 2*xs - 3*zs + 5 + noise

np.savez('TF_intro',inputs=generated_inputs,targets=generated_targets)

# %%
training_data = np.load('TF_intro.npz')

# %%
input_size = 2
output_size = 1

# Determining the model
model = tf.keras.Sequential([
                            tf.keras.layers.Dense(output_size,
                            kernel_initializer = tf.random_uniform_initializer(minval=-0.10,maxval=0.10),
                            bias_initializer = tf.random_uniform_initializer(minval=-0.10,maxval=0.10))
                            ])

custom_optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

#model.compile(optimizer = custom_optimizer,loss='mean_squared_error')
model.compile(optimizer = custom_optimizer,loss='huber_loss')

#early_stopping = tf.keras.callbacks.EarlyStopping(monitor='huber_loss',patience=2)
model.fit(training_data['inputs'], training_data['targets'], epochs = 200, verbose =2 )
# Out:
# Train on 1000 samples
# Epoch 1/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 16.4948
# Epoch 2/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 15.7990
# Epoch 3/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 15.1025
# Epoch 4/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 14.4150
# Epoch 5/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 13.7289
# Epoch 6/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 13.0457
# Epoch 7/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 12.3728
# Epoch 8/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 11.7132
# Epoch 9/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 11.0570
# Epoch 10/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 10.4094
# Epoch 11/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 9.7838
# Epoch 12/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 9.1600
# Epoch 13/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 8.5552
# Epoch 14/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 7.9670
# Epoch 15/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 7.4067
# Epoch 16/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 6.8875
# Epoch 17/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 6.3935
# Epoch 18/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 5.9482
# Epoch 19/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 5.5513
# Epoch 20/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 5.2076
# Epoch 21/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.9218
# Epoch 22/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.6896
# Epoch 23/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.5136
# Epoch 24/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.3830
# Epoch 25/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.2909
# Epoch 26/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.2236
# Epoch 27/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.1753
# Epoch 28/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.1340
# Epoch 29/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.0968
# Epoch 30/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.0635
# Epoch 31/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 4.0307
# Epoch 32/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.9991
# Epoch 33/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.9686
# Epoch 34/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.9373
# Epoch 35/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.9075
# Epoch 36/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.8766
# Epoch 37/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.8460
# Epoch 38/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.8161
# Epoch 39/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.7860
# Epoch 40/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.7551
# Epoch 41/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.7248
# Epoch 42/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.6946
# Epoch 43/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.6644
# Epoch 44/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.6348
# Epoch 45/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.6039
# Epoch 46/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.5740
# Epoch 47/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.5437
# Epoch 48/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.5134
# Epoch 49/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.4833
# Epoch 50/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.4531
# Epoch 51/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.4228
# Epoch 52/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.3926
# Epoch 53/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.3625
# Epoch 54/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.3323
# Epoch 55/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.3016
# Epoch 56/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.2718
# Epoch 57/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.2416
# Epoch 58/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.2113
# Epoch 59/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.1813
# Epoch 60/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.1511
# Epoch 61/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.1207
# Epoch 62/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.0909
# Epoch 63/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.0606
# Epoch 64/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.0306
# Epoch 65/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 3.0002
# Epoch 66/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.9699
# Epoch 67/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.9396
# Epoch 68/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.9097
# Epoch 69/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.8797
# Epoch 70/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.8494
# Epoch 71/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.8192
# Epoch 72/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.7892
# Epoch 73/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.7594
# Epoch 74/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.7291
# Epoch 75/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.6991
# Epoch 76/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.6689
# Epoch 77/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.6388
# Epoch 78/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.6086
# Epoch 79/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.5786
# Epoch 80/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.5484
# Epoch 81/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.5183
# Epoch 82/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.4883
# Epoch 83/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.4584
# Epoch 84/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.4283
# Epoch 85/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.3985
# Epoch 86/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.3684
# Epoch 87/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.3384
# Epoch 88/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.3086
# Epoch 89/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.2785
# Epoch 90/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.2484
# Epoch 91/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.2185
# Epoch 92/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.1884
# Epoch 93/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.1590
# Epoch 94/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.1285
# Epoch 95/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.0988
# Epoch 96/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.0687
# Epoch 97/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.0389
# Epoch 98/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 2.0092
# Epoch 99/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.9789
# Epoch 100/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.9494
# Epoch 101/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.9190
# Epoch 102/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.8891
# Epoch 103/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.8592
# Epoch 104/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.8295
# Epoch 105/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.7999
# Epoch 106/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.7698
# Epoch 107/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.7398
# Epoch 108/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.7103
# Epoch 109/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.6802
# Epoch 110/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.6505
# Epoch 111/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.6210
# Epoch 112/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.5909
# Epoch 113/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.5618
# Epoch 114/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.5322
# Epoch 115/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.5028
# Epoch 116/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.4733
# Epoch 117/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.4435
# Epoch 118/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.4144
# Epoch 119/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.3846
# Epoch 120/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.3557
# Epoch 121/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.3262
# Epoch 122/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.2971
# Epoch 123/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.2679
# Epoch 124/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.2391
# Epoch 125/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.2099
# Epoch 126/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.1811
# Epoch 127/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.1526
# Epoch 128/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.1241
# Epoch 129/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.0961
# Epoch 130/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.0684
# Epoch 131/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.0406
# Epoch 132/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 1.0133
# Epoch 133/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.9862
# Epoch 134/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.9591
# Epoch 135/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.9325
# Epoch 136/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.9068
# Epoch 137/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.8812
# Epoch 138/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.8559
# Epoch 139/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.8312
# Epoch 140/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.8070
# Epoch 141/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.7836
# Epoch 142/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.7606
# Epoch 143/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.7380
# Epoch 144/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.7159
# Epoch 145/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.6949
# Epoch 146/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.6738
# Epoch 147/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.6533
# Epoch 148/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.6336
# Epoch 149/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.6147
# Epoch 150/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5961
# Epoch 151/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5781
# Epoch 152/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5609
# Epoch 153/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5437
# Epoch 154/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5272
# Epoch 155/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.5116
# Epoch 156/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4963
# Epoch 157/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4816
# Epoch 158/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4675
# Epoch 159/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4537
# Epoch 160/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4408
# Epoch 161/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4282
# Epoch 162/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4160
# Epoch 163/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.4044
# Epoch 164/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3930
# Epoch 165/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3823
# Epoch 166/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3720
# Epoch 167/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3623
# Epoch 168/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3527
# Epoch 169/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3439
# Epoch 170/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3352
# Epoch 171/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3267
# Epoch 172/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3191
# Epoch 173/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3113
# Epoch 174/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.3043
# Epoch 175/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2974
# Epoch 176/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2908
# Epoch 177/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2844
# Epoch 178/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2784
# Epoch 179/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2726
# Epoch 180/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2672
# Epoch 181/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2620
# Epoch 182/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2570
# Epoch 183/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2524
# Epoch 184/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2480
# Epoch 185/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2435
# Epoch 186/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2395
# Epoch 187/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2355
# Epoch 188/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2318
# Epoch 189/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2283
# Epoch 190/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2251
# Epoch 191/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2220
# Epoch 192/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2190
# Epoch 193/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2161
# Epoch 194/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2135
# Epoch 195/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2110
# Epoch 196/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2088
# Epoch 197/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2064
# Epoch 198/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2045
# Epoch 199/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2023
# Epoch 200/200
# WARNING:tensorflow:Early stopping conditioned on metric `huber_loss` which is not available. Available metrics are: loss
# 1000/1000 - 0s - loss: 0.2004

# %%
# getting the weights and biases
model.layers[0].get_weights()
# Out:
# [array([[ 1.998823 ],
#         [-2.9950602]], dtype=float32),
#  array([4.752509], dtype=float32)]

# %%
val = model.predict_on_batch(training_data['inputs'])
#np.array(val).round(1)

# %%
plt.plot(np.squeeze(val),np.squeeze(training_data['targets']))
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()

# %%
val[1:10]
# Out:
# <tf.Tensor: id=13280, shape=(9, 1), dtype=float32, numpy=
# array([[ 11.188388 ],
#        [ 17.189762 ],
#        [  4.6526413],
#        [-24.727163 ],
#        [ -6.267474 ],
#        [ 26.62956  ],
#        [ 26.386436 ],
#        [  9.3839245],
#        [ 38.775208 ]], dtype=float32)>
